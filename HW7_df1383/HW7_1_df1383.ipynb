# %% [markdown]
# ## HW 7

# %%
# Import necessary packages

import pandas as pd

# %%
# Read drug use dataset into pandas dataframe

df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/drug-use-by-age/drug-use-by-age.csv')
df.head()
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana-frequency  cocaine-use cocaine-frequency  crack-use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
#
#   crack-frequency        ...          oxycontin-use oxycontin-frequency  \
# 0               -        ...                    0.1                24.5
# 1             3.0        ...                    0.1                41.0
# 2               -        ...                    0.4                 4.5
# 3             9.5        ...                    0.8                 3.0
# 4             1.0        ...                    1.1                 4.0
#
#    tranquilizer-use  tranquilizer-frequency  stimulant-use  \
# 0               0.2                    52.0            0.2
# 1               0.3                    25.5            0.3
# 2               0.9                     5.0            0.8
# 3               2.0                     4.5            1.5
# 4               2.4                    11.0            1.8
#
#   stimulant-frequency  meth-use  meth-frequency  sedative-use  \
# 0                 2.0       0.0               -           0.2
# 1                 4.0       0.1             5.0           0.1
# 2                12.0       0.1            24.0           0.2
# 3                 6.0       0.3            10.5           0.4
# 4                 9.5       0.3            36.0           0.2
#
#   sedative-frequency
# 0               13.0
# 1               19.0
# 2               16.5
# 3               30.0
# 4                3.0
#
# [5 rows x 28 columns]

# %%
# Print columns

df.columns
# Out:
# Index(['age', 'n', 'alcohol-use', 'alcohol-frequency', 'marijuana-use',
#        'marijuana-frequency', 'cocaine-use', 'cocaine-frequency', 'crack-use',
#        'crack-frequency', 'heroin-use', 'heroin-frequency', 'hallucinogen-use',
#        'hallucinogen-frequency', 'inhalant-use', 'inhalant-frequency',
#        'pain-releiver-use', 'pain-releiver-frequency', 'oxycontin-use',
#        'oxycontin-frequency', 'tranquilizer-use', 'tranquilizer-frequency',
#        'stimulant-use', 'stimulant-frequency', 'meth-use', 'meth-frequency',
#        'sedative-use', 'sedative-frequency'],
#       dtype='object')

# %%
# Select relevant columns needed for plot

drug_use = df[['age', 'alcohol-use', 'alcohol-frequency', 'marijuana-use',
       'marijuana-frequency', 'cocaine-use', 'cocaine-frequency']]
drug_use = drug_use[drug_use.age !='65+']

# %%
# Convert age column values that are ranges into average of range

drug_use1 = drug_use.replace('22-23', 22)
drug_use1 = drug_use1.replace('24-25', 24)
drug_use1 = drug_use1.replace('26-29', 26)
drug_use1 = drug_use1.replace('30-34', 30)
drug_use1 = drug_use1.replace('35-49', 35)
drug_use1 = drug_use1.replace('50-64', 50)
drug_use1 = drug_use1.replace('65+', 65)

drug_use1
# Out:
#    age  alcohol-use  alcohol-frequency  marijuana-use  marijuana-frequency  \
# 0   12          3.9                3.0            1.1                  4.0
# 1   13          8.5                6.0            3.4                 15.0
# 2   14         18.1                5.0            8.7                 24.0
# 3   15         29.2                6.0           14.5                 25.0
# 4   16         40.1               10.0           22.5                 30.0
# 5   17         49.3               13.0           28.0                 36.0
# 6   18         58.7               24.0           33.7                 52.0
# 7   19         64.6               36.0           33.4                 60.0
# 8   20         69.7               48.0           34.0                 60.0
# 9   21         83.2               52.0           33.0                 52.0
# 10  22         84.2               52.0           28.4                 52.0
# 11  24         83.1               52.0           24.9                 60.0
# 12  26         80.7               52.0           20.8                 52.0
# 13  30         77.5               52.0           16.4                 72.0
# 14  35         75.0               52.0           10.4                 48.0
# 15  50         67.2               52.0            7.3                 52.0
#
#     cocaine-use cocaine-frequency
# 0           0.1               5.0
# 1           0.1               1.0
# 2           0.1               5.5
# 3           0.5               4.0
# 4           1.0               7.0
# 5           2.0               5.0
# 6           3.2               5.0
# 7           4.1               5.5
# 8           4.9               8.0
# 9           4.8               5.0
# 10          4.5               5.0
# 11          4.0               6.0
# 12          3.2               5.0
# 13          2.1               8.0
# 14          1.5              15.0
# 15          0.9              36.0

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Scatter(
    x=drug_use1['age'],
    y=drug_use1['alcohol-frequency'],
    name='Frequency of Alcohol Use',
    line = dict(
        color = ('rgb(205, 12, 24)'),
        width = 3)
)
trace2 = go.Bar(
    x=drug_use1['age'],
    y=drug_use1['alcohol-use'],
    name='% who us Alcohol',
    yaxis='y2',
    marker = dict(
        color = ('rgb(205, 12, 24)'),
    ),
)

trace3 = go.Scatter(
    x=drug_use1['age'],
    y=drug_use1['marijuana-frequency'],
    name='Frequency of Marijuana Use',
    line = dict(
        color = ('rgb(22, 96, 167)'),
        width = 3)
)
trace4 = go.Bar(
    x=drug_use1['age'],
    y=drug_use1['marijuana-use'],
    name='% who use Marijuana',
    yaxis='y2',
    marker = dict(
        color = ('rgb(22, 96, 167)'),
    ),
)

trace5 = go.Scatter(
    x=drug_use1['age'],
    y=drug_use1['cocaine-frequency'],
    name='Frequency of Cocaine Use',
    line = dict(
        color = ('rgb(12, 200, 24)'),
        width = 3)
)
trace6 = go.Bar(
    x=drug_use1['age'],
    y=drug_use1['cocaine-use'],
    name='% who use Cocaine',
    yaxis='y2',
    marker=dict(
        color = 'rgb(12, 200, 24)'),
)

data = [trace3, trace4, trace5, trace6]
layout = go.Layout(
    barmode ='group',
    title='Drug Use',
    yaxis=dict(
        showgrid=False,
        title='% of Individuals in Age Group (Bar)'
    ),
    xaxis=dict(
        showgrid=False,
        title='Age'
    ),
    yaxis2=dict(
        showgrid=False,
        title='Frequency of Use (Line)',
        overlaying='y',
        side='right'
    ),
    showlegend=True,
    legend=dict(
        x=100,
        y=1.225,
    ),
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Drug Use')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~dfay88/393.embed" height="525px" width="100%"></iframe>
