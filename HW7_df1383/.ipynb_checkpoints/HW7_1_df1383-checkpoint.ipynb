# %% [markdown]
# ## HW 7

# %%
# Import necessary packages

import pandas as pd
import numpy as np

# %%
# Read drug use dataset into pandas dataframe

df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/drug-use-by-age/drug-use-by-age.csv')
df.head()
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana-frequency  cocaine-use cocaine-frequency  crack-use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
#
#   crack-frequency        ...          oxycontin-use oxycontin-frequency  \
# 0               -        ...                    0.1                24.5
# ...

# %%
# Print columns

df.columns
# Out:
# Index(['age', 'n', 'alcohol-use', 'alcohol-frequency', 'marijuana-use',
#        'marijuana-frequency', 'cocaine-use', 'cocaine-frequency', 'crack-use',
#        'crack-frequency', 'heroin-use', 'heroin-frequency', 'hallucinogen-use',
#        'hallucinogen-frequency', 'inhalant-use', 'inhalant-frequency',
#        'pain-releiver-use', 'pain-releiver-frequency', 'oxycontin-use',
#        'oxycontin-frequency', 'tranquilizer-use', 'tranquilizer-frequency',
#        'stimulant-use', 'stimulant-frequency', 'meth-use', 'meth-frequency',
#        'sedative-use', 'sedative-frequency'],
#       dtype='object')

# %%
# Select relevant columns needed for plot

drug_use = df[['age', 'alcohol-use', 'alcohol-frequency', 'marijuana-use',
       'marijuana-frequency', 'cocaine-use', 'cocaine-frequency']]
drug_use = drug_use[drug_use.age !='65+']

# %%
# Convert age column values that are ranges into average of range

drug_use1 = drug_use.replace('12', '12-13')
drug_use1 = drug_use1.replace('13', '13-14,')
drug_use1 = drug_use1.replace('14', '14-15')
drug_use1 = drug_use1.replace('15', '15-16,')
drug_use1 = drug_use1.replace('16', '16-17')
drug_use1 = drug_use1.replace('17', '17-18')
drug_use1 = drug_use1.replace('18', '18-19')
drug_use1 = drug_use1.replace('19', '19-20')
drug_use1 = drug_use1.replace('20', '20-21')
drug_use1 = drug_use1.replace('21', '21-22')

#drug_use_age = drug_use['age'].astype(str)
drug_use1
# Out:
#        age  alcohol-use alcohol-frequency  marijuana-use marijuana-frequency  \
# 0    12-13          3.9                 3            1.1                   4
# 1   13-14,          8.5                 6            3.4              15-16,
# 2    14-15         18.1                 5            8.7                  24
# 3   15-16,         29.2                 6           14.5                  25
# 4    16-17         40.1                10           22.5                  30
# 5    17-18         49.3            13-14,           28.0                  36
# 6    18-19         58.7                24           33.7                  52
# 7    19-20         64.6                36           33.4                  60
# 8    20-21         69.7                48           34.0                  60
# 9    21-22         83.2                52           33.0                  52
# 10   22-23         84.2                52           28.4                  52
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Scatter(
    x=drug_use_age,
    y=drug_use['alcohol-frequency'],
    name='Frequency of Alcohol Use',
    line = dict(
        color = ('rgb(205, 12, 24)'),
        width = 3)
)
trace2 = go.Bar(
    x=drug_use_age,
    y=drug_use['alcohol-use'],
    name='% who us Alcohol',
    yaxis='y2',
    marker = dict(
        color = ('rgb(205, 12, 24)'),
    ),
)

trace3 = go.Scatter(
    x=drug_use['age'],
    y=drug_use['marijuana-frequency'],
    name='Frequency of Marijuana Use',
    line = dict(
        color = ('rgb(22, 96, 167)'),
        width = 3)
)
trace4 = go.Bar(
    x=drug_use['age'],
    y=drug_use['marijuana-use'],
    name='% who use Marijuana',
    yaxis='y2',
    marker = dict(
        color = ('rgb(22, 96, 167)'),
    ),
)

trace5 = go.Scatter(
    x=drug_use1['age'],
    y=drug_use1['cocaine-frequency'],
    name='Frequency of Cocaine Use',
    yaxis='y2',
    line = dict(
        color = ('rgb(22, 96, 167)'),
        width = 3)
)
trace6 = go.Bar(
    x=drug_use1['age'],
    y=drug_use1['cocaine-use'],
    name='% who use Cocaine',
    marker=dict(
        color = 'rgb(205, 12, 24)'),
)

data = [trace6, trace5]
layout = go.Layout(
    barmode ='group',
    title='Drug Use',
    yaxis=dict(
        showgrid=False,
        title='% of Individuals in Age Group (Bar)',
        color='rgb(205, 12, 24)'
    ),
    xaxis=dict(
        showgrid=False,
        title='Age'
    ),
    yaxis2=dict(
        showgrid=False,
        title='Frequency of Use (Line)',
        color = 'rgb(22, 96, 167)',
        overlaying='y',
        side='right',
    ),
    showlegend=True,
    legend=dict(
        x=100,
        y=1.1,
    ),
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Drug Use')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~dfay88/393.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### Figure 1: Bar plot of the percentage of individuals who use cocaine in a given age group as well as a line plot of the frequency of use in each age group. Frequency of use is defined as the average number of times in a year the individuals in each age group use cocaine. Most notably, the plot illustrates the inverse relationship that as people get older they tend to use less cocaine however the indivdiuals who do use cocaine use it very frequently. Particularly the people betweent the ages of 50-64 who use it on average 36 times a year.
